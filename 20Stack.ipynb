# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/Riya/Downloads/stocks_3_levels.xlsx",header=[0,1,2])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df1=df.stack()
df1.head(10)
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_12520\1331420881.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df1=df.stack()
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...

# %%
df1=df.stack(level=2)
df1.head(10)
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_12520\3066358836.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df1=df.stack(level=2)
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...

# %%
df1=df.stack(level=1)
df1
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_12520\4037997224.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df1=df.stack(level=1)
#                                 Unnamed: 0_level_0 Price Ratios          \
#                                            Company     Facebook  Google
# 0 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
#   Price                                        NaN       155.00   955.0
#   Price to earnings ratio (P/E)                NaN        37.10    32.0
#   Unnamed: 0_level_1                       Q1 2016          NaN     NaN
# 1 Net Profit                                   NaN          NaN     NaN
# ...

# %%
df1=df1.unstack()
df1
# Out:
#   Unnamed: 0_level_0                                                \
#              Company
#           Net Profit Net Sales Price Price to earnings ratio (P/E)
# 0                NaN       NaN   NaN                           NaN
# 1                NaN       NaN   NaN                           NaN
# 2                NaN       NaN   NaN                           NaN
# 3                NaN       NaN   NaN                           NaN
# 4                NaN       NaN   NaN                           NaN
#
#                      Price Ratios                   \
#                          Facebook
#   Unnamed: 0_level_1   Net Profit Net Sales  Price
# 0            Q1 2016          NaN       NaN  155.0
# 1            Q2 2016          NaN       NaN  150.0
# 2            Q3 2016          NaN       NaN  153.0
# 3            Q4 2016          NaN       NaN  155.0
# 4            Q1 2017          NaN       NaN  156.0
#
# ...
