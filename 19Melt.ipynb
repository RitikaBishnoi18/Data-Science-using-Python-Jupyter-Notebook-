# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Riya/Downloads/weather.csv")
df.head(10)
# Out:
#          day  chicago temp  chennai temp  berlin temp chicago type  \
# 0     Monday            32            75           41        sunny
# 1    Tuesday            30            77           43       cloudy
# 2  Wednesday            28            75           45        rainy
# 3   Thursday            22            82           38        sunny
# 4     Friday            30            83           30        rainy
# 5   Saturday            20            81           45       cloudy
# 6     Sunday            25            77           47        sunny
#
#   chennai type berlin type
# 0        sunny       sunny
# 1        rainy       sunny
# 2       cloudy      cloudy
# 3        sunny       sunny
# 4        sunny       sunny
# 5       cloudy       rainy
# 6        sunny      cloudy

# %%
df2=pd.melt(df,id_vars="day")
print(df2)
# Out:
#           day      variable   value
# 0      Monday  chicago temp      32
# 1     Tuesday  chicago temp      30
# 2   Wednesday  chicago temp      28
# 3    Thursday  chicago temp      22
# 4      Friday  chicago temp      30
# 5    Saturday  chicago temp      20
# 6      Sunday  chicago temp      25
# 7      Monday  chennai temp      75
# 8     Tuesday  chennai temp      77
# 9   Wednesday  chennai temp      75
# 10   Thursday  chennai temp      82
# 11     Friday  chennai temp      83
# 12   Saturday  chennai temp      81
# 13     Sunday  chennai temp      77
# 14     Monday   berlin temp      41
# 15    Tuesday   berlin temp      43
# 16  Wednesday   berlin temp      45
# 17   Thursday   berlin temp      38
# 18     Friday   berlin temp      30
# 19   Saturday   berlin temp      45
# 20     Sunday   berlin temp      47
# 21     Monday  chicago type   sunny
# 22    Tuesday  chicago type  cloudy
# 23  Wednesday  chicago type   rainy
# 24   Thursday  chicago type   sunny
# ...

# %%
df2=pd.melt(df,id_vars="day",value_vars=["chicago temp","chennai temp","berlin temp"],var_name="Temperature")
print(df2)
# Out:
#           day   Temperature  value
# 0      Monday  chicago temp     32
# 1     Tuesday  chicago temp     30
# 2   Wednesday  chicago temp     28
# 3    Thursday  chicago temp     22
# 4      Friday  chicago temp     30
# 5    Saturday  chicago temp     20
# 6      Sunday  chicago temp     25
# 7      Monday  chennai temp     75
# 8     Tuesday  chennai temp     77
# 9   Wednesday  chennai temp     75
# 10   Thursday  chennai temp     82
# 11     Friday  chennai temp     83
# 12   Saturday  chennai temp     81
# 13     Sunday  chennai temp     77
# 14     Monday   berlin temp     41
# 15    Tuesday   berlin temp     43
# 16  Wednesday   berlin temp     45
# 17   Thursday   berlin temp     38
# 18     Friday   berlin temp     30
# 19   Saturday   berlin temp     45
# 20     Sunday   berlin temp     47

# %%
df2=pd.melt(df,id_vars="day",value_vars=["chicago type","chennai type","berlin type"],var_name="Day Type")
print(df2)
# Out:
#           day      Day Type   value
# 0      Monday  chicago type   sunny
# 1     Tuesday  chicago type  cloudy
# 2   Wednesday  chicago type   rainy
# 3    Thursday  chicago type   sunny
# 4      Friday  chicago type   rainy
# 5    Saturday  chicago type  cloudy
# 6      Sunday  chicago type   sunny
# 7      Monday  chennai type   sunny
# 8     Tuesday  chennai type   rainy
# 9   Wednesday  chennai type  cloudy
# 10   Thursday  chennai type   sunny
# 11     Friday  chennai type   sunny
# 12   Saturday  chennai type  cloudy
# 13     Sunday  chennai type   sunny
# 14     Monday   berlin type   sunny
# 15    Tuesday   berlin type   sunny
# 16  Wednesday   berlin type  cloudy
# 17   Thursday   berlin type   sunny
# 18     Friday   berlin type   sunny
# 19   Saturday   berlin type   rainy
# 20     Sunday   berlin type  cloudy
