# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Riya/Downloads/weather.csv")
df
# Out:
#          day  chicago temp  chennai temp  berlin temp chicago type  \
# 0     Monday            32            75           41        sunny
# 1    Tuesday            30            77           43       cloudy
# 2  Wednesday            28            75           45        rainy
# 3   Thursday            22            82           38        sunny
# 4     Friday            30            83           30        rainy
# 5   Saturday            20            81           45       cloudy
# 6     Sunday            25            77           47        sunny
#
#   chennai type berlin type
# 0        sunny       sunny
# 1        rainy       sunny
# 2       cloudy      cloudy
# 3        sunny       sunny
# 4        sunny       sunny
# 5       cloudy       rainy
# 6        sunny      cloudy

# %%
df1=df.drop("berlin type",axis=1)
df1
# Out:
#          day  chicago temp  chennai temp  berlin temp chicago type  \
# 0     Monday            32            75           41        sunny
# 1    Tuesday            30            77           43       cloudy
# 2  Wednesday            28            75           45        rainy
# 3   Thursday            22            82           38        sunny
# 4     Friday            30            83           30        rainy
# 5   Saturday            20            81           45       cloudy
# 6     Sunday            25            77           47        sunny
#
#   chennai type
# 0        sunny
# 1        rainy
# 2       cloudy
# 3        sunny
# 4        sunny
# 5       cloudy
# 6        sunny

# %%
save=df.pop("berlin type")
print(df)
# Out:
#          day  chicago temp  chennai temp  berlin temp chicago type
# 0     Monday            32            75           41        sunny
# 1    Tuesday            30            77           43       cloudy
# 2  Wednesday            28            75           45        rainy
# 3   Thursday            22            82           38        sunny
# 4     Friday            30            83           30        rainy
# 5   Saturday            20            81           45       cloudy
# 6     Sunday            25            77           47        sunny

# %%
print(save)
# Out:
# 0     sunny
# 1     sunny
# 2    cloudy
# 3     sunny
# 4     sunny
# 5     rainy
# 6    cloudy
# Name: berlin type, dtype: object

# %%
del df["chicago type"]
print(df)
# Out:
#          day  chicago temp  chennai temp  berlin temp
# 0     Monday            32            75           41
# 1    Tuesday            30            77           43
# 2  Wednesday            28            75           45
# 3   Thursday            22            82           38
# 4     Friday            30            83           30
# 5   Saturday            20            81           45
# 6     Sunday            25            77           47
